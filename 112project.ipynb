# %%
import pandas as pd

# %%
df =  pd.read_csv('C:\\Users\\hp\\Documents\\web_scraping project\\HRDataset_v14.csv') 

df.head(10)
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
# 5         Anderson, Linda    10002          0                0         0
# 6           Andreola, Colby  10194          0                0         0
# 7               Athwal, Sam  10062          0                4         1
# 8          Bachiochi, Linda  10114          0                0         0
# 9        Bacong, Alejandro   10250          0                2         1
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# ...

# %% [markdown]
# Data Cleaning

# %%
print(f" ==> count rows and column  : {df.shape}")
print("----------------------------------\n")
print(f"==> columns name \n\n: {df.columns}")
# Out:
#  ==> count rows and column  : (311, 40)
# ----------------------------------
#
# ==> columns name
#
# : Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences', 'PerformanceScore_num', 'IsActive', 'Age', 'Ecart_Age'],
#       dtype='object')

# %%
df['Employee_Name']= df['Employee_Name'].str.replace(',', '')

# %%
df.head(10)
# Out:
#              Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi Wilson  K  10026          0                0         1
# 1  Ait Sidi Karthikeyan     10084          1                1         1
# 2         Akinkuolie Sarah  10196          1                1         0
# 3              AlagbeTrina  10088          1                1         0
# 4          Anderson Carol   10069          0                2         0
# 5         Anderson Linda    10002          0                0         0
# 6           Andreola Colby  10194          0                0         0
# 7               Athwal Sam  10062          0                4         1
# 8          Bachiochi Linda  10114          0                0         0
# 9        Bacong Alejandro   10250          0                2         1
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# ...

# %%
n = df.groupby('RecruitmentSource')['Employee_Name'].count()
n
# Out:
# RecruitmentSource
# CareerBuilder              23
# Diversity Job Fair         29
# Employee Referral          31
# Google Search              49
# Indeed                     87
# LinkedIn                   76
# On-line Web application     1
# Other                       2
# Website                    13
# Name: Employee_Name, dtype: int64

# %%
def Convertir_formats(df):
    df['DOB'] = pd.to_datetime(df['DOB'], errors='coerce')
    df['DateofHire'] = pd.to_datetime(df['DateofHire'], errors='coerce')
    df['DateofTermination'] = pd.to_datetime(df['DateofTermination'], errors='coerce')
    df['Salary'] = pd.to_numeric(df['Salary'], errors='coerce')
    df['Absences']= pd.to_numeric(df['Absences'], errors='coerce')
    
    return df

    Convertir_formats(df)

# %%
def define_data(df):

    print(f'shape of the data: {df.shape} \n')
    print("-----------------------------------\n")
    print(f'mean valur manquent =>> {df["DateofTermination"].isna().mean() * 100}')
    print("-----------------------------------\n")
    print(f'diplicated rows {df.duplicated().sum()} \n')
    print("-----------------------------------\n")

    print(f'missing values in each column:\n {df.isna().sum()} \n')
    print("-----------------------------------\n")

    print(f'data types in the dataframe:\n {df.dtypes} \n')
define_data(df)
# Out:
# shape of the data: (311, 40)
#
# -----------------------------------
#
# mean valur manquent =>> 66.55948553054662
# -----------------------------------
#
# diplicated rows 0
#
# -----------------------------------
#
# missing values in each column:
#  Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                           100
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# ...

# %%
print(f'Moyenne des absences: {df["Absences"].mean()}')
print(f'Mode du score de performance: {df["PerformanceScore"].mode()}')
# Out:
# Moyenne des absences: 10.237942122186496
# Mode du score de performance: 0    Fully Meets
# Name: PerformanceScore, dtype: object

# %%
df['Absences'].quantile([0.25, 0.5, 0.75])
# Out:
# 0.25     5.0
# 0.50    10.0
# 0.75    15.0
# Name: Absences, dtype: float64

# %%
df['Salary'].quantile([0.25, 0.5, 0.75])
# Out:
# 0.25    55501.5
# 0.50    62810.0
# 0.75    72036.0
# Name: Salary, dtype: float64

# %%
df['Absences'].var()
# Out:
# np.float64(34.25287833212323)

# %%
print("Moyenne du salaire :", df['Salary'].mean())

# Médiane
print("Médiane du salaire :", df['Salary'].median())

# Mode
print("Mode du salaire :", df['Salary'].mode()[0])  # [0] pour afficher la valeur

# Quartiles
quartiles = df['Salary'].quantile([0.25, 0.5, 0.75])
print("Quartiles du salaire :\n", quartiles)

# Variance
print("Variance du salaire :", df['Salary'].var())

# Écart-type
print("Écart-type du salaire :", df['Salary'].std())
# Out:
# Moyenne du salaire : 69020.6848874598
# Médiane du salaire : 62810.0
# Mode du salaire : 57815
# Quartiles du salaire :
#  0.25    55501.5
# 0.50    62810.0
# 0.75    72036.0
# Name: Salary, dtype: float64
# Variance du salaire : 632856381.6100613
# Écart-type du salaire : 25156.636929646644

# %%
import matplotlib.pyplot as plt

# Compter le nombre d'employés par PerformanceScore
counts = df['PerformanceScore'].value_counts()

# Pie chart correct
plt.figure(figsize=(6,6))
counts.plot(kind='pie', autopct='%1.1f%%', colors=['#1f77b4','#ff7f0e','#2ca02c','#d62728'])
plt.title("Répartition des performances des employés")
plt.ylabel("")  # Supprime le label y inutile
plt.show()

# %%
mapping = {'Needs Improvement':0, 'PIP':0, 'Fully Meets':1, 'Exceeds':2}
df['PerformanceScore_num'] = df['PerformanceScore'].map(mapping)

# %%
df_sorted = df.sort_values(by='Salary', ascending=False)

# %%
sns.histplot(df['Absences'], bins=20)
plt.show()

# Boxplot salaire
sns.boxplot(x=df['Salary'])
plt.show()



# Compter le nombre d'employés par PerformanceScore
counts = df['PerformanceScore'].value_counts()

# Pie chart correct
plt.figure(figsize=(6,6))
counts.plot(kind='pie', autopct='%1.1f%%', colors=['#1f77b4','#ff7f0e','#2ca02c','#d62728'])
plt.title("Répartition des performances des employés")
plt.ylabel("")  # Supprime le label y inutile
plt.show()

# %%
df[df['Salary'] >= 200000]['Position']
# Out:
# 150    President & CEO
# 308                CIO
# Name: Position, dtype: object

# %%
#si logique de voir les outliers parce que les salaires très élevés
#peuvent être justifiés par certains postes Sr ou des rôles de direction
Q1 = df['Salary'].quantile(0.25)
Q3 = df['Salary'].quantile(0.75)
IQR = Q3 - Q1
outliers = df[(df['Salary'] < Q1 - 1.5*IQR) | (df['Salary'] > Q3 + 1.5*IQR)]
outliers['Position'].unique()
# Out:
# array(['Sr. DBA', 'Database Administrator', 'Enterprise Architect',
#        'Sr. Accountant', 'BI Director', 'Director of Operations',
#        'Software Engineer', 'IT Manager - Support', 'IT Director',
#        'BI Developer', 'Director of Sales', 'President & CEO',
#        'IT Manager - Infra', 'Principal Data Architect', 'Data Architect',
#        'IT Manager - DB', 'Sr. Network Engineer', 'CIO'], dtype=object)

# %%
# Histogramme du salaire
plt.figure(figsize=(8,5))
sns.histplot(df['Salary'], bins=20, kde=True)  # kde=True ajoute une courbe de densité
plt.title('Distribution des salaires')
plt.xlabel('Salary')
plt.ylabel('Nombre d’employés')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(y=df['Salary'])
plt.title('Boxplot du salaire')
plt.show()

plt.figure(figsize=(10,6))
sns.boxplot(x='Department', y='Salary', data=df)
plt.xticks(rotation=45)
plt.title('Salaire par département')
plt.show()

# %%
df['Department'].unique()
# Out:
# array(['Production       ', 'IT/IS', 'Software Engineering',
#        'Admin Offices', 'Sales', 'Executive Office'], dtype=object)

# %%
df['Department'] = df['Department'].str.strip()
df['Department'].unique()
# Out:
# array(['Production', 'IT/IS', 'Software Engineering', 'Admin Offices',
#        'Sales', 'Executive Office'], dtype=object)

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Department', data=df)
plt.xticks(rotation=45)
plt.title('Nombre d’employés par département')
plt.show()  

dept_counts = df['Department'].value_counts()
plt.figure(figsize=(6,6))
plt.pie(dept_counts, labels=dept_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Répartition des employés par département')
plt.show()

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences', 'PerformanceScore_num'],
#       dtype='object')

# %% [markdown]
# Data Wrangling

# %%
df.isna().sum()
df['DateofTermination'].isna().mean()*100
# si logique de voir les valeurs nan parce que si un employé n'a pas de date de fin, il est actif
df['IsActive'] = df['DateofTermination'].isna()
df[['IsActive','Employee_Name']].head()
# Out:
#    IsActive            Employee_Name
# 0      True       Adinolfi Wilson  K
# 1     False  Ait Sidi Karthikeyan
# 2     False         Akinkuolie Sarah
# 3      True              AlagbeTrina
# 4     False          Anderson Carol

# %%
df['DOB'] = pd.to_datetime(df['DOB'], errors='coerce')
df['DOB'].unique()
# Out:
# <DatetimeArray>
# ['1983-07-10 00:00:00', '2075-05-05 00:00:00', '1988-09-19 00:00:00',
#  '1988-09-27 00:00:00', '1989-09-08 00:00:00', '1977-05-22 00:00:00',
#  '1979-05-24 00:00:00', '1983-02-18 00:00:00', '2070-02-11 00:00:00',
#  '1988-01-07 00:00:00',
#  ...
#  '1987-05-24 00:00:00', '1983-07-30 00:00:00', '2069-10-02 00:00:00',
#  '2058-11-07 00:00:00', '1985-04-20 00:00:00', '1985-05-11 00:00:00',
#  '1982-05-04 00:00:00', '1979-08-30 00:00:00', '1979-02-24 00:00:00',
#  '1978-08-17 00:00:00']
# Length: 307, dtype: datetime64[ns]

# %%
today = pd.Timestamp.today()
df["Age"] = (today - df["DOB"]).dt.days // 365

df[['Age', 'Employee_Name']].head()
df.loc[df['Age'] < 0, ['Age', 'DOB']]
# Out:
#      Age        DOB
# 1    -50 2075-05-05
# 8    -45 2070-02-11
# 10   -49 2074-01-12
# 11   -49 2074-02-21
# 16   -41 2066-04-17
# ..   ...        ...
# 290  -43 2068-10-10
# 296  -30 2055-11-14
# 301  -40 2065-09-09
# 303  -44 2069-10-02
# 304  -33 2058-11-07
#
# [100 rows x 2 columns]

# %%
mask_invalid = (df['Age'] < 0) | (df['DOB'] > pd.Timestamp.today())
df.loc[mask_invalid, ['Age', 'DOB']] = pd.NA

df[['Age', 'DOB']]
# Out:
#       Age        DOB
# 0    42.0 1983-07-10
# 1     NaN        NaT
# 2    37.0 1988-09-19
# 3    37.0 1988-09-27
# 4    36.0 1989-09-08
# ..    ...        ...
# 306  40.0 1985-05-11
# 307  43.0 1982-05-04
# 308  46.0 1979-08-30
# 309  46.0 1979-02-24
# 310  47.0 1978-08-17
#
# [311 rows x 2 columns]

# %%
import numpy as np
pivot_dept = df.pivot_table(values="Salary", index="Department", aggfunc=np.mean)
pivot_dept
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_24820\1894807679.py:2: FutureWarning: The provided callable <function mean at 0x0000023E4E08E340> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot_dept = df.pivot_table(values="Salary", index="Department", aggfunc=np.mean)
#                              Salary
# Department
# Admin Offices          71791.888889
# Executive Office      250000.000000
# IT/IS                  97064.640000
# Production             59953.545455
# Sales                  69061.258065
# Software Engineering   94989.454545

# %%
pivot_role = df.pivot_table(values="Salary", index="Position", aggfunc=np.median)
pivot_role.head()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_24820\3951343365.py:1: FutureWarning: The provided callable <function median at 0x0000023E4E1B2AC0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   pivot_role = df.pivot_table(values="Salary", index="Position", aggfunc=np.median)
#                             Salary
# Position
# Accountant I               63003.0
# Administrative Assistant   51920.0
# Area Sales Manager         63695.0
# BI Developer               96370.0
# BI Director               110929.0

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x="Age", y="Salary", hue="Position", data=df)
plt.title("Relation entre âge et salaire (segmentation par rôle)")
plt.show()

# %%
mean_age = df['Age'].mean()
min_age = df['Age'].min()
max_age = df['Age'].max()

print("Moyenne  Age :", mean_age)
print("Age min :", min_age)
print("Age max :", max_age)

# Écart = différence entre chaque valeur et la moyenne
df['Ecart_Age'] = df['Age'] - mean_age
df[['Age','Ecart_Age']]
# Out:
# Moyenne Age : 41.39810426540284
# Age min : 33.0
# Age max : 50.0
#       Age  Ecart_Age
# 0    42.0   0.601896
# 1     NaN        NaN
# 2    37.0  -4.398104
# 3    37.0  -4.398104
# 4    36.0  -5.398104
# ..    ...        ...
# 306  40.0  -1.398104
# 307  43.0   1.601896
# 308  46.0   4.601896
# 309  46.0   4.601896
# 310  47.0   5.601896
#
# [311 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences', 'PerformanceScore_num', 'IsActive', 'Age', 'Ecart_Age'],
#       dtype='object')

# %%
cols_to_use = df[["Employee_Name", "Department", "PerformanceScore_num", "Absences",'Position']]

# %% [markdown]
# visualisation

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Department', data=df)
plt.xticks(rotation=45)
plt.title('Nombre d’employés par département')
plt.show()  

dept_counts = df['Department'].value_counts()
plt.figure(figsize=(6,6))
plt.pie(dept_counts, labels=dept_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Répartition des employés par département')
plt.show()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1) 
sns.boxplot(y="PerformanceScore_num", data=cols_to_use, color="skyblue")
plt.title("Distribution des scores de performance")
plt.ylabel("Score")
plt.xlabel("")
# Out:
# Text(0.5, 0, '')

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences', 'PerformanceScore_num', 'IsActive', 'Age', 'Ecart_Age'],
#       dtype='object')

# %%
df['Absences'].unique()
# Out:
# array([ 1, 17,  3, 15,  2, 19,  4, 16, 12,  9,  7, 20,  8, 13,  5, 14,  6,
#        11, 10, 18])

# %%
df.loc[df['PerformanceScore_num'] == 0, ['Employee_Name', 'Position','Absences']].head()
# Out:
#        Employee_Name                  Position  Absences
# 23     Blount Dianna  Production Technician II         3
# 53      Cole Spencer   Production Technician I        16
# 54  Corleone Michael        Production Manager         3
# 67      Delarge Alex        Area Sales Manager         5
# 69    Desimone Carl    Production Technician I         9

# %%
plt.subplot(1, 2, 2) 
sns.boxplot(y="Absences", data=cols_to_use, color="lightcoral")
plt.title("Distribution des absences")
plt.ylabel("Nombre d'absences")
plt.xlabel("")
plt.tight_layout() 
plt.show()

# %%
sns.countplot(x='PerformanceScore', data=df)
plt.title("Nombre d'employés par performance")
plt.show()

# %%
sns.barplot(x='Position', y='PerformanceScore_num', data=cols_to_use, estimator='mean')
plt.xticks(rotation=90)
plt.title("Performance moyenne par poste")
plt.show()

# %%
df.groupby('Position')['PerformanceScore_num'].mean().sort_values().plot(kind='bar')
plt.xticks(rotation=90)
#plt.xticks(rotation=45, ha='right')
plt.title("Performance moyenne par poste")
plt.show()

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences', 'PerformanceScore_num', 'IsActive', 'Age', 'Ecart_Age'],
#       dtype='object')

# %%
df.groupby('Department')['Salary'].mean().plot(kind='bar')
plt.xticks(rotation=90)
plt.title("Salaire total par département")
plt.show()
